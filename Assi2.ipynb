# %%
"""
1. What are the two values of the Boolean data type? How do you write them?

Ans: True and False.
     
     Declaration : a = True      |   b = False    |  20 > 2      |  100 <50      |  a = 2
                   Type(a)       |   Type(b)      |              |               |  b = 6
                                 |                |              |               |  if(a==b):
                   o/p - Bool    |   o/p - Bool   |  o/p - True  |  o/p - False  |   print(True)
                    
     



"""

# %%
"""
2. What are the three different types of Boolean operators?

Ans:  1) AND
      2) OR
      3) NOT
"""

# %%
"""
3. Make a list of each Boolean operator's truth tables
(i.e. every possible combination of Boolean values for the operator and what it evaluate ).

Ans:    AND Operator:
                         X   |  Y    | X and Y
                       TRUE  | TRUE  |  TRUE
                       FALSE | TRUE  |  FALSE
                       TRUE  | FALSE |  FALSE
                       FALSE | FALSE |  FALSE
                       
                       
                       
       OR Operator:
                       
                       X     |  Y    |  X OR Y
                      TRUE   | TRUE  |  TRUE
                      TRUE   | FALSE |  TRUE
                      FALSE  | TRUE  |  TRUE
                      FALSE  | FALSE |  FALSE
                       
                       
       NOT Operator :
       
                      X      |  NOT X
                     TRUE    | FALSE
                     FALSE   | TRUE
                
            
            
                       
"""

# %%
"""
4. What are the values of the following expressions?
(5 > 4) and (3 == 5)
not (5 > 4)
(5 > 4) or (3 == 5)
not ((5 > 4) or (3 == 5))
(True and True) and (True == False)
(not False) or (not True)

Ans:                                            
                                    EXPRESSIONS                        |       VALUES
                                                                       | 
                               (5 > 4) and (3 == 5)                    |       FALSE
                                                                       |       
                               not (5 > 4)                             |       FALSE   
                                                                       |
                               (5 > 4) or (3 == 5)                     |       TRUE 
                                                                       |
                               not ((5 > 4) or (3 == 5))               |       FALSE
                                                                       |
                               (True and True) and (True == False)     |       FALSE
                                                                       |
                               (not False) or (not True)               |       TRUE

                               


"""

# %%
"""
5. What are the six comparison operators?

Ans:  six operators are given below :
       
       1) <
       2) >
       3) >=
       4) <=
       5) ==
       6) !=




"""

# %%
 """
6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.
 
Ans: When we want to assign value to the variable we make use of Assignment Operator.
     When we have to check if the operands on both the sides are equal or not we make use of equal to operator.
     ex:
     
                  a = 3 # assigning value (3) to the a
                  b = 9
                  if (a == b): # checking if the both operands are equal or not
                    print(TRUE)
                  else:
                    print(FALSE)




 """

# %%
"""
7. Identify the three blocks in this code:
spam = 0
if spam == 10:
print('eggs')
if spam > 5:
print('bacon')
else:
print('ham')
print('spam')
print('spam')

Ans:  1st block:         | 2nd block:     | 3rd block:
      if spam == 10:     | if spam > 5:   | else:
       print('eggs')     | print('bacon') | print('ham')
                         |                | print('spam')
                         |                | print('spam')

"""

# %%
"""
8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam,
and prints Greetings! if anything else is stored in spam.

Ans:    spam = int(input())
        if(spam == 1):
          print("Hello")
        elif (spam == 2 ):
          print("Howdy")
        else:
          print("Greetings!")

"""

# %%
"""
9.If your programme is stuck in an endless loop, what keys you’ll press?
Ans:
       CNTRL+C

"""

# %%
"""
10. How can you tell the difference between break and continue?

Ans: when break encounters in the loop then the loop will be ended whereas the continue will end the loop and again
     will go thestarting point of the loop.

"""

# %%
"""
11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?

Ans: There won't be any difference. 



"""

# %%
"""
12. Write a short program that prints the numbers 1 to 10 using a for loop.
Then write an equivalent program that prints the numbers 1 to 10 using a while loop.

Ans: 1) Using For loop:-

       for i in range(1,11):
          print(i)
___________________________________________________________________________________________________________________________________         
    
     2) Using While loop:-
    
       i = 1
       while(i<=10):
           print(i)
           i+=1
                

"""

# %%
"""
13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?

Ans: spam.bacon()


"""
